# %%
print("hello world")
# Out:
# hello world

# %%
a=10
b=a
a=30
print(a,b)
print(id(a),id(b))
# Out:
# 30 10
# 11646280 11645640

# %%
a = int(input ("enter a number"))
print (a)
print(type(a))

# %%
#integer
a=4
print(a)
print(type(a))

#float
b=1.2
print(b)
print(type(b))

#string
c="string"
print(c)
print(type(c))

#boolean
d= True
print (d)
print(type(d))

# %% [markdown]
# immporting and using modules

# %%
#import module
#import math
#print(math.factorial(5))
#print(math.pow(5,2))
#print(math.pi)
#print(math.floor(10.7234))
#print(math.ceil(10.0123))

#example 2
import math as rajendra
#print(rajendra.factorial(5))
#print(rajendra.pow(5,2))
#print(rajendra.pi)
#print(rajendra.floor(10.7234))
#print(rajendra.ceil(10.0123))

#example 3
from math import factorial
print(factorial(5))

#example 4
from math import *
print(pow(5,3))
print(pi)
print(floor(10.7234))
# Out:
# 120
# 125.0
# 3.141592653589793
# 10
