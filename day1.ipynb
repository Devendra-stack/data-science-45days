# %%
print("hello world")
# Out:
# hello world

# %%
a=10
b=a
a=30
print(a,b)
print(id(a),id(b))
# Out:
# 30 10
# 11646280 11645640

# %%
a = int(input ("enter a number"))
print (a)
print(type(a))

# %%
#integer
a=4
print(a)
print(type(a))

#float
b=1.2
print(b)
print(type(b))

#string
c="string"
print(c)
print(type(c))

#boolean
d= True
print (d)
print(type(d))
