# %% [markdown]
# **panda **
# panda is a python library used for
# 1. reading data
# 2. cleaning data
# 3. analyzing data
# 4. manipulating data

# %%
import pandas as pd
df = pd.Series([10,20,30])
print(df)
print(df[0])
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64
# 10

# %%
#dic
import pandas as pd
dict =  {"name":["dheeraj", "kunal","dev","raj","abhishek"],
        "age":[10,12,23,45,34],
         "salary":[{"in hand":"15000", "ctc":"1.2lpa"},{"in hand":"20000", "ctc":"2.2lpa"},
                   {"in hand":"25000", "ctc":"2.4lpa"},{"in hand":"30000", "ctc":"3.0lpa"},
                   {"in hand":"35000", "ctc":"3.2lpa"}]}
df= pd.Series(dict)

print(df)
df = pd.DataFrame(dict)
print(df)
# Out:
# name                   [dheeraj, kunal, dev, raj, abhishek]
# age                                    [10, 12, 23, 45, 34]
# salary    [{'in hand': '15000', 'ctc': '1.2lpa'}, {'in h...
# dtype: object
#        name  age                                 salary
# 0   dheeraj   10  {'in hand': '15000', 'ctc': '1.2lpa'}
# 1     kunal   12  {'in hand': '20000', 'ctc': '2.2lpa'}
# 2       dev   23  {'in hand': '25000', 'ctc': '2.4lpa'}
# 3       raj   45  {'in hand': '30000', 'ctc': '3.0lpa'}
# 4  abhishek   34  {'in hand': '35000', 'ctc': '3.2lpa'}

# %% [markdown]
# save and load data as csv , excel and json files

# %%
#csv
import pandas as pd
url="https://raw.githubusercontent.com/Devendra-stack/data-science-45days/main/file1.csv"
df = pd.read_csv(url)
print(df)
# Out:
#        name  roll no
# 0   dheeraj      123
# 1     kunal     1234
# 2  abhishek    12345
# 3   praveen    12356
# 4    anjali  1234567

# %%
#json
import pandas as pd
url="https://raw.githubusercontent.com/Devendra-stack/data-science-45days/main/file2.json"
df = pd.read_json(url)
#print(df)

#head(2) -> prints starting 2 rows
print(df.head(2))
print(df.head(-1))
#negative numbers removes rows from downwards
# Out:
#       name  roll no  marks
# 0  dheeraj      123     10
# 1    kunal     1234     20
#        name  roll no  marks
# 0   dheeraj      123     10
# 1     kunal     1234     20
# 2  abhishek    12345     30
# 3   praveen    12356     40

# %%
import pandas as pd
url="https://raw.githubusercontent.com/Devendra-stack/data-science-45days/main/file2.json"
df = pd.read_json(url)
print(df.tail(-1))
#tail is used to print the rows from last
print(df.tail(3))
# Out:
#        name  roll no  marks
# 1     kunal     1234     20
# 2  abhishek    12345     30
# 3   praveen    12356     40
# 4    anjali  1234567     50
#        name  roll no  marks
# 2  abhishek    12345     30
# 3   praveen    12356     40
# 4    anjali  1234567     50

# %%
import pandas as pd
url="https://raw.githubusercontent.com/Devendra-stack/data-science-45days/main/file2.json"
df = pd.read_json(url)
df.shape
# Out:
# (5, 3)

# %%
import pandas as pd
url="https://raw.githubusercontent.com/Devendra-stack/data-science-45days/main/file2.json"
df = pd.read_json(url)
df.info()

#df.info(verbose=True)

df.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     5 non-null      object
#  1   roll no  5 non-null      int64
#  2   marks    5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 252.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Columns: 3 entries, name to marks
# dtypes: int64(2), object(1)
# memory usage: 252.0+ bytes

# %%
#rename
import pandas as pd
url="https://raw.githubusercontent.com/Devendra-stack/data-science-45days/main/file2.json"
df = pd.read_json(url)
df.rename(columns={"name":"student_name","marks":"salary"},inplace=True)#->permanently chenges the name of column
print(df)
# Out:
#   student_name  roll no  salary
# 0      dheeraj      123      10
# 1        kunal     1234      20
# 2     abhishek    12345      30
# 3      praveen    12356      40
# 4       anjali  1234567      50

# %%
#describe function
import pandas as pd
url="https://raw.githubusercontent.com/Devendra-stack/data-science-45days/main/file2.json"
df = pd.read_json(url)
df.marks.describe()
# Out:
# count     5.000000
# mean     30.000000
# std      15.811388
# min      10.000000
# 25%      20.000000
# 50%      30.000000
# 75%      40.000000
# max      50.000000
# Name: marks, dtype: float64

# %%
#example on above operations-> head,tail,shape,info,rename,describe
import pandas as pd
data = {
        "Emp_ID" : [101,102,103,104,105,106],
        "Name" : [ "Amit","riya","raj", "Sara", "John","Neha" ],
        "Department" : ["IT"," HR"," Finance", "IT","Sales","HR"],
        "Salary" : [50000,45000,60000,55000,48000,52000],
        "Experience":[ 2,3,4,5,4,1]
}
df= pd.DataFrame(data)
df
df.head(2)
df.tail(4)
df.shape
#df.info()
df.rename(columns={"Name":"Empl_name"},inplace=True)
#df.Salary.describe()
df
# Out:
#    Emp_ID Empl_name Department  Salary  Experience
# 0     101      Amit         IT   50000           2
# 1     102      riya         HR   45000           3
# 2     103       raj    Finance   60000           4
# 3     104      Sara         IT   55000           5
# 4     105      John      Sales   48000           4
# 5     106      Neha         HR   52000           1

# %%
import pandas as pd
d = {
    "name":["vishal","virat","vineet"], # 3 rows
    "salary":[100,200,300] # 3 rows
}
df = pd.DataFrame(data=d)
#adding column
# df["marks"] = [10,20,30]
df["marks"] = df["salary"] / 2
df
# Out:
#      name  salary  marks
# 0  vishal     100   50.0
# 1   virat     200  100.0
# 2  vineet     300  150.0
